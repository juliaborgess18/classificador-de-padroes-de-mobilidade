# %% [markdown]
# # Processa o dataset das mobilidades que deseja mesclar

# %%
import pandas as pd
from scripts.funcoes.pipeline import processar_dados

df_andando = processar_dados("C:\\classificador-de-padroes-de-mobilidade\\dataset\\andando\\dados.xlsx")
# df_caindo = processar_dados("C:\\classificador-de-padroes-de-mobilidade\\dataset\\caindo\\dados.xlsx")
df = pd.read_excel("C:\\classificador-de-padroes-de-mobilidade\\dataset\\caindo\\dados.xlsx")

# df_andando = df_andando.head(100)
df
# df = pd.concat([df_andando, df_correndo])

# df_embaralhada = df.sample(frac=1).reset_index(drop=True)
# Out:
#        id   acelX   acelY   acelZ    girX     girY     girZ  idTipoMovimento  \
# 0   12388  4052.0  -569.0  -997.0  3296.0   -140.0    237.0                3
# 1   12389  3650.0  -621.0 -1573.0  3232.0  -3974.0  -1047.0                3
# 2   12390  3211.0 -1850.0 -1638.0  3312.0   5905.0  -5151.0                3
# 3   12391   767.0  1984.0 -1297.0  3312.0   -468.0   4863.0                3
# 4   12392   -56.0   921.0 -3639.0  3312.0  -1239.0   4265.0                3
# 5   12393  -186.0  1817.0 -3628.0  3296.0   1937.0  -1366.0                3
# 6   12394  4075.0   -94.0  -771.0  3408.0   5118.0   3020.0                3
# 7   12395  3791.0 -1833.0 -1136.0  3520.0   5602.0 -10975.0                3
# 8   12396  2596.0  -309.0 -1106.0  3440.0   5396.0   -225.0                3
# 9   12397  7538.0 -1749.0 -5075.0  3488.0  -8985.0 -12039.0                3
# 10  12398  2661.0  1104.0 -2729.0  3584.0   1565.0   2695.0                3
# ...

# %%
df_embaralhada.to_excel("C:\\classificador-de-padroes-de-mobilidade\\results\\planilhas\\andando_correndo.xlsx", index=False)
