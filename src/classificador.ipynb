# %%
# Instalar as dependências do projeto
! pip install -r ../requirements.txt

# %%
from leitura_dados import LeituraDados

arquivo = "..\\dataset\\Andando-PausasNãoMarcadas.csv"

LeituraDados.resultado(arquivo)
# Out:
#            X        Y       Z
# 0     3465.0  -2115.0   986.0
# 1     3131.0  -1980.0   418.0
# 2     1438.0   -588.0  3494.0
# 3     1281.0   -326.0  4320.0
# 4     1365.0   -840.0  2588.0
# ...      ...      ...     ...
# 1687  2264.0   -816.0  2951.0
# 1688  2994.0  -2699.0   317.0
# 1689  3084.0  -1936.0  -443.0
# 1690 -3316.0   1776.0  1006.0
# 1691  2232.0  16548.0  -484.0
#
# [1692 rows x 3 columns]
