# %%
# Instalar as dependências do projeto
! pip install -r ../requirements.txt

# %%
# Importando bibliotecas
from scripts.leitura_dados import LeituraDados
from scripts.min_max_dados import MinimoMaximoDados
from scripts.gera_grafico import GeraGraficoMagnitudeAceleracao
from scripts.calcula_zscore import CalculaZScore
from scripts.calcula_norma_euclidiana import CalculaNormaEuclidiana

# %%
arquivo = "..\\dataset\\Andando-PausasNãoMarcadas.csv"

# Leitura dos dados de acordo com a extensão do arquivo
df = LeituraDados.resultado(arquivo)

# %%
# Adicionar coluna de cálculo da Magnitude da aceleração
df = CalculaNormaEuclidiana.resultado(df)

# %%
# Obtendo valor mínimo e máximo da magnitude de aceleração
valor_minimo = MinimoMaximoDados.resultado(df['MAGNITUDE_ACEL'])[0]
valor_maximo = MinimoMaximoDados.resultado(df['MAGNITUDE_ACEL'])[1]
print(valor_minimo, valor_maximo)
# Out:
# 2174.207441804944 16704.861088916605

# %%
# Cálculo de Z-Score para retirar os outliers dos dados
df = CalculaZScore.resultado(df)

# %%
# Gráfico da aceleração com os dados já tratados
GeraGraficoMagnitudeAceleracao.resultado(df)
# Out:
# c:\Users\julia\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\julia\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
